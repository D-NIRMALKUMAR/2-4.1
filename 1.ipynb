# %%
import gradio as gr

def chatbot(message, history):
    return message

app = gr.ChatInterface(fn=chatbot)
app.launch()
# Out:
#   Cell In[4], line 4
#     return message
#     ^
# SyntaxError: invalid non-printable character U+00A0
